# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
from PIL import Image, ImageFilter

# %%
img = cv2.imread('T1_0027_S14.png')
mask = cv2.imread('Ground/T1_0002_S8.png',0)
res = cv2.bitwise_and(img,img,mask = mask)

# %%
plt.imshow(img)
plt.show()
plt.imshow(res)
plt.show()

# %%
#L1 line
# Window name in which image is displayed
window_name = 'Image'
#np.sort(corners)
# Start coordinate, here (0, 0)
# represents the top left corner of image
# x1,y1 = corners[1]
# x1= int(x1)
# y1= int(y1)
start_pointL1 = (164,55)
centroid1 = ( int((164+211)/2), int((55+97)/2) )
centroid2 = ( int((154+206)/2), int((94+137)/2) )
centroid3 = ( int((145+196)/2), int((133+173)/2) )
centroid4 = ( int((140+188)/2), int((176+217)/2) )
centroid5 = ( int((150+204)/2), int((204+256)/2) )
# End coordinate, here (250, 250)
# represents the bottom right corner of image
# x2,y2 = corners[2]
# x2= int(x2)
# y2= int(y2)
end_pointL1 = (211,97)

# Green color in BGR
color = (0, 255, 0)

# Line thickness of 9 px
thickness = 1

# Using cv2.line() method
# Draw a diagonal green line with thickness of 1 px
line_imageL1 = cv2.line(img, centroid1, centroid2, color, thickness)
line_imageL1 = cv2.line(line_imageL1, centroid2, centroid3, color, thickness)
line_imageL1 = cv2.line(line_imageL1, centroid3, centroid4, color, thickness)
line_imageL1 = cv2.line(line_imageL1, centroid4, centroid5, color, thickness)
line_imageL1 = cv2.line(line_imageL1, centroid5, centroid1, color, thickness)
    
plt.imshow(line_imageL1)
plt.show()

# %%
from shapely.geometry import Polygon
coords  = (centroid1,centroid2,centroid3,centroid4,centroid5)
polygon = Polygon(coords)
area = polygon.area
print(area)
# Out:
# 1243.5

# %%
img = cv2.imread('T1_0027_S14.png')

start_pointL1 = (164,55)
end_pointL1 = (211,97)

centroid1 = ( int((164+211)/2), int((55+97)/2) )
perpendicular1 = ( int((164+211)/2), int((55+97)/2) + 25 )

centroid2 = ( int((154+206)/2), int((94+137)/2) )
perpendicular2 = ( int((154+206)/2), int((94+137)/2) + 25)

centroid3 = ( int((145+196)/2), int((133+173)/2) )
perpendicular3 = ( int((145+196)/2), int((133+173)/2) + 25)

centroid4 = ( int((140+188)/2), int((176+217)/2) )
perpendicular4 = ( int((140+188)/2), int((176+217)/2) + 25)

centroid5 = ( int((150+204)/2), int((204+256)/2) )
perpendicular5 = ( int((150+204)/2), int((204+256)/2) + 25)

centroid6 = ( int((176+229)/2), int((234+276)/2) )
perpendicular6 = ( int((176+229)/2), int((234+276)/2) + 25)


# Green color in BGR
color = (0, 255, 0)
colorR = (255, 0, 0)

# Line thickness of 9 px
thickness = 1

# Using cv2.line() method
# Draw a diagonal green line with thickness of 1 px
line_imageL1 = cv2.line(img, centroid1, centroid2, color, thickness)
line_imageL1 = cv2.line(line_imageL1, centroid1, perpendicular1, colorR, thickness)

line_imageL1 = cv2.line(line_imageL1, centroid2, centroid3, color, thickness)
line_imageL1 = cv2.line(line_imageL1, centroid2, perpendicular2, colorR, thickness)

line_imageL1 = cv2.line(line_imageL1, centroid3, centroid4, color, thickness)
line_imageL1 = cv2.line(line_imageL1, centroid3, perpendicular3, colorR, thickness)

line_imageL1 = cv2.line(line_imageL1, centroid4, centroid5, color, thickness)
line_imageL1 = cv2.line(line_imageL1, centroid4, perpendicular4, colorR, thickness)

line_imageL1 = cv2.line(line_imageL1, centroid5, centroid6, color, thickness)
line_imageL1 = cv2.line(line_imageL1, centroid5, perpendicular5, colorR, thickness)


plt.imshow(line_imageL1)
plt.show()

# %%
img = cv2.imread('T1_0027_S14.png')

start_pointL1 = (164,55)
end_pointL1 = (211,97)

centroid1 = ( int((164+211)/2), int((55+97)/2) )
perpendicular1 = ( int((164+211)/2), int((55+97)/2) + 25 )

centroid2 = ( int((154+206)/2), int((94+137)/2) )
perpendicular2 = ( int((154+206)/2), int((94+137)/2) + 25)

centroid3 = ( int((145+196)/2), int((133+173)/2) )
perpendicular3 = ( int((145+196)/2), int((133+173)/2) + 25)

centroid4 = ( int((140+188)/2), int((176+217)/2) )
perpendicular4 = ( int((140+188)/2), int((176+217)/2) + 25)

centroid5 = ( int((150+204)/2), int((204+256)/2) )
perpendicular5 = ( int((150+204)/2), int((204+256)/2) + 25)

centroid6 = ( int((176+229)/2), int((234+276)/2) )
perpendicular6 = ( int((176+229)/2), int((234+276)/2) + 25)


# Green color in BGR
color = (0, 255, 0)
colorR = (255, 0, 0)

# Line thickness of 9 px
thickness = 3

# Using cv2.line() method
# Draw a diagonal green line with thickness of 1 px
line_imageL1 = cv2.line(img, centroid1, centroid2, color, thickness)

line_imageL1 = cv2.line(line_imageL1, centroid2, centroid3, color, thickness)

line_imageL1 = cv2.line(line_imageL1, centroid3, centroid4, color, thickness)

line_imageL1 = cv2.line(line_imageL1, centroid4, centroid5, color, thickness)

line_imageL1 = cv2.line(line_imageL1, centroid5, centroid6, color, thickness)

line_imageL1 = cv2.line(line_imageL1, centroid6, centroid1, color, thickness)

plt.imshow(line_imageL1)
plt.show()

# %%
from math import atan2, degrees, radians
import math
def angleOf3Points(A, B, C):
    Ax, Ay = A[0]-B[0], A[1]-B[1]
    Cx, Cy = C[0]-B[0], C[1]-B[1]
    a = atan2(Ay, Ax)
    c = atan2(Cy, Cx)
    if a < 0: a += math.pi*2
    if c < 0: c += math.pi*2
    return (math.pi*2 + c - a) if a > c else (c - a)

# %%
angleL1 = angle(centroid2,centroid1,perpendicular1)
angleL2 = angle(centroid3,centroid2,perpendicular2)
angleL3 = angle(centroid4,centroid3,perpendicular3)
angleL4 = angle(centroid5,centroid4,perpendicular4)
angleL5 = angle(centroid6,centroid5,perpendicular5)

print(angleL1)
print(angleL2)
print(angleL3)
print(angleL4)
print(angleL5)
# Out:
# 6.105589139896098
# 6.025861592208497
# 6.144545570045429
# 0.36520144978817304
# 0.7853981633974483

# %%
import statistics
angleList = [angleL1, angleL2, angleL3, angleL4, angleL5]
meanAngle = statistics.mean(angleList)
sd = statistics.stdev(angleList)

anterior = meanAngle + sd
posterior = meanAngle - sd
print(meanAngle)
print(sd)
print(anterior)
print(posterior)
print(angleList)
# Out:
# 3.885319183067129
# 3.025572819256048
# 6.910892002323177
# 0.8597463638110812
# [6.105589139896098, 6.025861592208497, 6.144545570045429, 0.36520144978817304, 0.7853981633974483]

# %%
i=0
print("Normal range: " + str(posterior) + " - " + str(anterior))
for angle in angleList:
    i=i+1
    if angle > anterior:
        print("Anterior " + "dislocation of L"+str(i) + "\tAngle: "+ str(angle))
    elif angle < posterior:
        print("Posterior " + "dislocation of L"+str(i) + "\tAngle: "+ str(angle))
    elif angle < anterior and angle > posterior:
        print("Normal " + "position of L" +str(i) + "\tAngle: "+ str(angle))
# Out:
# Normal range: 0.8597463638110812 - 6.910892002323177
# Normal position of L1	Angle: 6.105589139896098
# Normal position of L2	Angle: 6.025861592208497
# Normal position of L3	Angle: 6.144545570045429
# Posterior dislocation of L4	Angle: 0.36520144978817304
# Posterior dislocation of L5	Angle: 0.7853981633974483

# %%
a = 5.666667
b = "{:.2f}".format(a)
print(b)
# Out:
# 5.67

# %%
import pandas as pd

df = pd.read_csv('coordinates2.csv')

# %%
import pandas as pd

df = pd.read_csv('coordinates3.csv')

# %%
print(len(df))
# Out:
# 9

# %%
centroidList = []
perpendicularList = []
for x in range(len(df)):
  centroid = ( int((df.iloc[x,2]+df.iloc[x,4])/2), int((df.iloc[x,3]+df.iloc[x,5])/2) )
  centroidList.append(centroid)
  perpendicular = ( int((df.iloc[x,2]+df.iloc[x,4])/2), int((df.iloc[x,3]+df.iloc[x,5])/2) + 25 )
  perpendicularList.append(perpendicular)
    
centroidList = sorted(centroidList , key=lambda k: [k[1], k[0]])
perpendicularList = sorted(perpendicularList , key=lambda k: [k[1], k[0]])

print(centroidList)
print(perpendicularList)

for i in range((len(df) - 6)):
    centroidList.pop(0)
    perpendicularList.pop(0)
    
print(centroidList)
print(perpendicularList)
# Out:
# [(581, 47), (552, 131), (520, 251), (489, 379), (468, 518), (459, 655), (496, 786), (564, 866), (566, 868)]
# [(581, 72), (552, 156), (520, 276), (489, 404), (468, 543), (459, 680), (496, 811), (564, 891), (566, 893)]
# [(489, 379), (468, 518), (459, 655), (496, 786), (564, 866), (566, 868)]
# [(489, 404), (468, 543), (459, 680), (496, 811), (564, 891), (566, 893)]

# %%
cars = ['l1', 'l2', 'l3','l4', 's1', 'l5','l12', 'l13', 'l25']

cars.sort()
print(cars)

if len(cars) > 6:
    n = len(cars) - 6
    del cars[:n]
    print(cars)
# Out:
# ['l1', 'l12', 'l13', 'l2', 'l25', 'l3', 'l4', 'l5', 's1']
# ['l2', 'l25', 'l3', 'l4', 'l5', 's1']

# %%
print(centroidList)
print(perpendicularList)

    
for i in range(len(df)-(len(df) - 5)):
    #print(centroidList[len(df)-1-i])
    angleL = angleOf3Points(centroidList[len(df)-1-i],centroidList[len(df)-2-i],perpendicularList[len(df)-2-i])
    print(angleL)
# Out:
# [(581, 47), (552, 131), (520, 251), (489, 379), (468, 518), (459, 655), (496, 786), (564, 866), (566, 868)]
# [(581, 72), (552, 156), (520, 276), (489, 404), (468, 543), (459, 680), (496, 811), (564, 891), (566, 893)]
# 0.7853981633974483
# 0.7044940642422176
# 0.27527242304563915
# 6.217586135348547
# 6.13324013660614

# %%
centroid1 = ( int((df.iloc[0,2]+df.iloc[0,4])/2), int((df.iloc[0,3]+df.iloc[0,5])/2) )
perpendicular1 = ( int((df.iloc[0,2]+df.iloc[0,4])/2), int((df.iloc[0,3]+df.iloc[0,5])/2) + 25 )

centroid2 = ( int((df.iloc[1,2]+df.iloc[1,4])/2), int((df.iloc[1,3]+df.iloc[1,5])/2) )
perpendicular2 = ( int((df.iloc[1,2]+df.iloc[1,4])/2), int((df.iloc[1,3]+df.iloc[1,5])/2) + 25 )

centroid3 = ( int((df.iloc[2,2]+df.iloc[2,4])/2), int((df.iloc[2,3]+df.iloc[2,5])/2) )
perpendicular3 = ( int((df.iloc[2,2]+df.iloc[2,4])/2), int((df.iloc[2,3]+df.iloc[2,5])/2) + 25 )

centroid4 = ( int((df.iloc[3,2]+df.iloc[3,4])/2), int((df.iloc[3,3]+df.iloc[3,5])/2) )
perpendicular4 = ( int((df.iloc[3,2]+df.iloc[3,4])/2), int((df.iloc[3,3]+df.iloc[3,5])/2) + 25 )

centroid5 = ( int((df.iloc[4,2]+df.iloc[4,4])/2), int((df.iloc[4,3]+df.iloc[4,5])/2) )
perpendicular5 = ( int((df.iloc[4,2]+df.iloc[4,4])/2), int((df.iloc[4,3]+df.iloc[4,5])/2) + 25 )

centroid6 = ( int((df.iloc[5,2]+df.iloc[5,4])/2), int((df.iloc[5,3]+df.iloc[5,5])/2) )
perpendicular6 = ( int((df.iloc[5,2]+df.iloc[5,4])/2), int((df.iloc[5,3]+df.iloc[5,5])/2) + 25 )


centroidList = [centroid1, centroid2, centroid3, centroid4, centroid5, centroid6]
centroidList = sorted(centroidList , key=lambda k: [k[1], k[0]])
print(centroidList)

perpendicularList = [perpendicular1, perpendicular2, perpendicular3, perpendicular4, perpendicular5, perpendicular6]
perpendicularList = sorted(perpendicularList , key=lambda k: [k[1], k[0]])
print(perpendicularList)
# Out:
# [(160, 73), (151, 110), (141, 150), (136, 192), (137, 228), (157, 259)]
# [(160, 98), (151, 135), (141, 175), (136, 217), (137, 253), (157, 284)]

# %%
centroid1 = centroidList[0]
centroid2 = centroidList[1]
centroid3 = centroidList[2]
centroid4 = centroidList[3]
centroid5 = centroidList[4]
centroid6 = centroidList[5]

perpendicular1 = perpendicularList[0]
perpendicular2 = perpendicularList[1]
perpendicular3 = perpendicularList[2]
perpendicular4 = perpendicularList[3]
perpendicular5 = perpendicularList[4]
perpendicular6 = perpendicularList[5]
# Out:
# (141, 150)
# (141, 175)

# %%
blur2 = cv2.GaussianBlur(res,(7,7),cv2.BORDER_DEFAULT)
plt.imshow(blur2)
plt.show()

# %%
ret, thresh1 = cv2.threshold(blur2, 50, 255, cv2.THRESH_BINARY)
plt.imshow(thresh1)
plt.show()

# %%
original = res.copy()
gray = cv2.cvtColor(res, cv2.COLOR_BGR2GRAY)
thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

# Morph open to remove noise
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5,5))
opening = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, kernel, iterations=1)

# Find contours, obtain bounding box, extract and save ROI
ROI_number = 0
cnts = cv2.findContours(opening, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = cnts[0] if len(cnts) == 2 else cnts[1]
for c in cnts:
    x,y,w,h = cv2.boundingRect(c)
    y = y - 4
    x = x - 5
    w = w + 10
    h = h + 10
    #cv2.rectangle(original, (x, y), (x + w , y + h), (36,255,12), 1)
    cv2.rectangle(original, (x, y), (x + w , y + h), (0,0,0), 1)
    ROI = original[y:y+h, x:x+w]
    cv2.imwrite('ROI_{}.png'.format(ROI_number), ROI)
    ROI_number += 1

print(cnts[0].size)
# plt.imshow(original)
# plt.show()
cropL1 = cv2.imread('ROI_5.png')
plt.imshow(cropL1)
plt.show()
cropS1 = cv2.imread('ROI_0.png')
plt.imshow(cropS1)
plt.show()
# Out:
# 126

# %%
testBlurL1 = cv2.GaussianBlur(cropL1,(7,7),cv2.BORDER_DEFAULT)
plt.imshow(testBlurL1)
plt.show()
retL1, cropThreshL1 = cv2.threshold(testBlurL1, 50, 255, cv2.THRESH_BINARY)
# plt.imshow(cropThreshL1)
# plt.show()

testBlurS1 = cv2.GaussianBlur(cropS1,(7,7),cv2.BORDER_DEFAULT)
plt.imshow(testBlurS1)
plt.show()
retS1, cropThreshS1 = cv2.threshold(testBlurS1, 50, 255, cv2.THRESH_BINARY)
# plt.imshow(cropThreshS1)
# plt.show()

# %%
cropBlurL1 = cv2.GaussianBlur(cropL1,(5,5),cv2.BORDER_DEFAULT)
plt.imshow(cropBlurL1)
plt.show()

gray = cv2.cvtColor(cropBlurL1,cv2.COLOR_BGR2GRAY)

# find Harris corners
gray = np.float32(gray)
dst = cv2.cornerHarris(gray,2,3,0.04)
dst = cv2.dilate(dst,None)
ret, dst = cv2.threshold(dst,0.01*dst.max(),255,0)
dst = np.uint8(dst)

# find centroids
ret, labels, stats, centroids = cv2.connectedComponentsWithStats(dst)

# define the criteria to stop and refine the corners
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 100, 0.001)
corners = cv2.cornerSubPix(gray,np.float32(centroids),(5,5),(-1,-1),criteria)

# Now draw them
res = np.hstack((centroids,corners))
res = np.int0(res)
#blur[res[:,1],res[:,0]]=[0,0,255]
cropBlurL1[res[:,3],res[:,2]] = [0,255,0]

plt.imshow(cropBlurL1)
plt.show()
cv2.imwrite('cornersCropL1.png',cropBlurL1)
#print(type(corners))
#print(res.size)
# Out:
# True

# %%
cropBlurS1 = cv2.GaussianBlur(cropS1,(5,5),cv2.BORDER_DEFAULT)
plt.imshow(cropBlurS1)
plt.show()

gray = cv2.cvtColor(cropBlurS1,cv2.COLOR_BGR2GRAY)

# find Harris corners
gray = np.float32(gray)
dst = cv2.cornerHarris(gray,2,3,0.04)
dst = cv2.dilate(dst,None)
ret, dst = cv2.threshold(dst,0.01*dst.max(),255,0)
dst = np.uint8(dst)

# find centroids
ret, labels, stats, centroids2 = cv2.connectedComponentsWithStats(dst)

# define the criteria to stop and refine the corners
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 100, 0.001)
corners2 = cv2.cornerSubPix(gray,np.float32(centroids2),(5,5),(-1,-1),criteria)

# Now draw them
res = np.hstack((centroids2,corners2))
res = np.int0(res)
#blur[res[:,1],res[:,0]]=[0,0,255]
cropBlurS1[res[:,3],res[:,2]] = [0,255,0]

plt.imshow(cropBlurS1)
plt.show()
cv2.imwrite('cornersCropS1.png',cropBlurS1)
#print(type(corners))
#print(res.size)
# Out:
# True

# %%
#L1 line
# Window name in which image is displayed
window_name = 'Image'
#np.sort(corners)
# Start coordinate, here (0, 0)
# represents the top left corner of image
x1,y1 = corners[1]
x1= int(x1)
y1= int(y1)
start_pointL1 = (x1,y1)

# End coordinate, here (250, 250)
# represents the bottom right corner of image
x2,y2 = corners[2]
x2= int(x2)
y2= int(y2)
end_pointL1 = (x2,y2)

# Green color in BGR
color = (0, 255, 0)

# Line thickness of 9 px
thickness = 1

# Using cv2.line() method
# Draw a diagonal green line with thickness of 1 px
line_imageL1 = cv2.line(cropBlurL1, start_pointL1, end_pointL1, color, thickness)
    
plt.imshow(line_imageL1)
plt.show()

# %%
#S1 line
# Window name in which image is displayed
window_name = 'Image'
#np.sort(corners)
# Start coordinate, here (0, 0)
# represents the top left corner of image
x3,y3 = corners2[3]
x3= int(x3)
y3= int(y3)
start_pointS1 = (x3,y3)

# End coordinate, here (250, 250)
# represents the bottom right corner of image
x4,y4 = corners2[1]
x4= int(x4)
y4= int(y4)
end_pointS1 = (x4,y4)

# Green color in BGR
color = (0, 255, 0)

# Line thickness of 9 px
thickness = 1

# Using cv2.line() method
# Draw a diagonal green line with thickness of 9 px
line_imageS1 = cv2.line(cropBlurS1, start_pointS1, end_pointS1, color, thickness)
    
plt.imshow(line_imageS1)
plt.show()

# %%
def slopeCalculation(x1, y1, x2, y2):
    m = (y2-y1)/(x2-x1)
    #m = (324-(y2-y1))/(x2-x1)
    return m

# %%
def angleCalculation(slope1, slope2):
    slope = (slope1 - slope2) / (1 + slope1 * slope2)
    angle = np.arctan(slope)
    return angle

# %%
#slope calculation
slopeL1 = slopeCalculation(x1,y1,x2,y2)
slopeS1 = slopeCalculation(x3,y3,x4,y4)
#slopeL5 = slopeCalculation(x5,y5,x6,y6)

angleLLA = angleCalculation(slopeL1, slopeS1)
#angleLSA = angleCalculation(slopeL5, slopeS1)
print(angleLLA)
#print(angleLSA)
# Out:
# 0.816427337467024

# %%
import math
degree = math.degrees(angleLLA)
print(degree)
# Out:
# 46.777840715963464
